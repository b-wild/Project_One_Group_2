# %% [markdown]
# ### Data Exploration and Cleanup - Weather Data

# %%
# Dependencies
import requests
import pandas as pd
from config import api_key

# %%
# Establish base URL 
city = "Washington DC"
base_url = "https://api.weatherapi.com/v1/history.json?key=" + api_key + "&q=" + city + "&dt="

# %%
# Create list of 365 dates in Weather API format.
import datetime
date = datetime.datetime.strptime("2022-02-06", "%Y-%m-%d")
K=365
date_generated = pd.date_range(date, periods=K)
date_list = date_generated.astype(dtype=str)
date_list

print(date_list)
# Out:
# Index(['2022-02-06', '2022-02-07', '2022-02-08', '2022-02-09', '2022-02-10',
#        '2022-02-11', '2022-02-12', '2022-02-13', '2022-02-14', '2022-02-15',
#        ...
#        '2023-01-27', '2023-01-28', '2023-01-29', '2023-01-30', '2023-01-31',
#        '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05'],
#       dtype='object', length=365)

# %%
# Define an empty list to store the weather data
dc_weather = []

# Create for loop to gather API data and add it to created Pandas DataFrame.
for day in date_list:
    url = base_url + day
    response = requests.get(url).json()

    date = response['forecast']['forecastday'][0]['date']
    maxtemp_f = response['forecast']['forecastday'][0]['day']['maxtemp_f']
    mintemp_f = response['forecast']['forecastday'][0]['day']['mintemp_f']
    avgtemp_f = response['forecast']['forecastday'][0]['day']['avgtemp_f']
    totalprecip_in = response['forecast']['forecastday'][0]['day']['totalprecip_in']
    avghumidity = response['forecast']['forecastday'][0]['day']['avghumidity']
    day_condition = response['forecast']['forecastday'][0]['day']['condition']['text']
    temp_f_0 = response['forecast']['forecastday'][0]['hour'][0]['temp_f']
    condition_0 = response['forecast']['forecastday'][0]['hour'][0]['condition']['text']
    precip_in_0 = response['forecast']['forecastday'][0]['hour'][0]['precip_in']
    humidity_0 = response['forecast']['forecastday'][0]['hour'][0]['humidity']
    temp_f_1 = response['forecast']['forecastday'][0]['hour'][1]['temp_f']
    condition_1 = response['forecast']['forecastday'][0]['hour'][1]['condition']['text']
    precip_in_1 = response['forecast']['forecastday'][0]['hour'][1]['precip_in']
    humidity_1 = response['forecast']['forecastday'][0]['hour'][1]['humidity']
    temp_f_2 = response['forecast']['forecastday'][0]['hour'][2]['temp_f']
    condition_2 = response['forecast']['forecastday'][0]['hour'][2]['condition']['text']
    precip_in_2 = response['forecast']['forecastday'][0]['hour'][2]['precip_in']
    humidity_2 = response['forecast']['forecastday'][0]['hour'][2]['humidity']
    temp_f_3 = response['forecast']['forecastday'][0]['hour'][3]['temp_f']
    condition_3 = response['forecast']['forecastday'][0]['hour'][3]['condition']['text']
    precip_in_3 = response['forecast']['forecastday'][0]['hour'][3]['precip_in']
    humidity_3 = response['forecast']['forecastday'][0]['hour'][3]['humidity']
    temp_f_4 = response['forecast']['forecastday'][0]['hour'][4]['temp_f']
    condition_4 = response['forecast']['forecastday'][0]['hour'][4]['condition']['text']
    precip_in_4 = response['forecast']['forecastday'][0]['hour'][4]['precip_in']
    humidity_4 = response['forecast']['forecastday'][0]['hour'][4]['humidity']
    temp_f_4 = response['forecast']['forecastday'][0]['hour'][4]['temp_f']
    condition_4 = response['forecast']['forecastday'][0]['hour'][4]['condition']['text']
    precip_in_4 = response['forecast']['forecastday'][0]['hour'][4]['precip_in']
    humidity_4 = response['forecast']['forecastday'][0]['hour'][4]['humidity']
    temp_f_5 = response['forecast']['forecastday'][0]['hour'][5]['temp_f']
    condition_5 = response['forecast']['forecastday'][0]['hour'][5]['condition']['text']
    precip_in_5 = response['forecast']['forecastday'][0]['hour'][5]['precip_in']
    humidity_5 = response['forecast']['forecastday'][0]['hour'][5]['humidity']
    temp_f_6 = response['forecast']['forecastday'][0]['hour'][6]['temp_f']
    condition_6 = response['forecast']['forecastday'][0]['hour'][6]['condition']['text']
    precip_in_6 = response['forecast']['forecastday'][0]['hour'][6]['precip_in']
    humidity_6 = response['forecast']['forecastday'][0]['hour'][6]['humidity']
    temp_f_7 = response['forecast']['forecastday'][0]['hour'][7]['temp_f']
    condition_7 = response['forecast']['forecastday'][0]['hour'][7]['condition']['text']
    precip_in_7 = response['forecast']['forecastday'][0]['hour'][7]['precip_in']
    humidity_7 = response['forecast']['forecastday'][0]['hour'][7]['humidity']
    temp_f_8 = response['forecast']['forecastday'][0]['hour'][8]['temp_f']
    condition_8 = response['forecast']['forecastday'][0]['hour'][8]['condition']['text']
    precip_in_8 = response['forecast']['forecastday'][0]['hour'][8]['precip_in']
    humidity_8 = response['forecast']['forecastday'][0]['hour'][8]['humidity']
    temp_f_9 = response['forecast']['forecastday'][0]['hour'][9]['temp_f']
    condition_9 = response['forecast']['forecastday'][0]['hour'][9]['condition']['text']
    precip_in_9 = response['forecast']['forecastday'][0]['hour'][9]['precip_in']
    humidity_9 = response['forecast']['forecastday'][0]['hour'][9]['humidity']
    temp_f_10 = response['forecast']['forecastday'][0]['hour'][10]['temp_f']
    condition_10 = response['forecast']['forecastday'][0]['hour'][10]['condition']['text']
    precip_in_10 = response['forecast']['forecastday'][0]['hour'][10]['precip_in']
    humidity_10 = response['forecast']['forecastday'][0]['hour'][10]['humidity']
    temp_f_11 = response['forecast']['forecastday'][0]['hour'][11]['temp_f']
    condition_11 = response['forecast']['forecastday'][0]['hour'][11]['condition']['text']
    precip_in_11 = response['forecast']['forecastday'][0]['hour'][11]['precip_in']
    humidity_11 = response['forecast']['forecastday'][0]['hour'][11]['humidity']
    temp_f_12 = response['forecast']['forecastday'][0]['hour'][12]['temp_f']
    condition_12 = response['forecast']['forecastday'][0]['hour'][12]['condition']['text']
    precip_in_12 = response['forecast']['forecastday'][0]['hour'][12]['precip_in']
    humidity_12 = response['forecast']['forecastday'][0]['hour'][12]['humidity']
    temp_f_13 = response['forecast']['forecastday'][0]['hour'][13]['temp_f']
    condition_13 = response['forecast']['forecastday'][0]['hour'][13]['condition']['text']
    precip_in_13 = response['forecast']['forecastday'][0]['hour'][13]['precip_in']
    humidity_13 = response['forecast']['forecastday'][0]['hour'][13]['humidity']
    temp_f_14 = response['forecast']['forecastday'][0]['hour'][14]['temp_f']
    condition_14 = response['forecast']['forecastday'][0]['hour'][14]['condition']['text']
    precip_in_14 = response['forecast']['forecastday'][0]['hour'][14]['precip_in']
    humidity_14 = response['forecast']['forecastday'][0]['hour'][14]['humidity']
    temp_f_15 = response['forecast']['forecastday'][0]['hour'][15]['temp_f']
    condition_15 = response['forecast']['forecastday'][0]['hour'][15]['condition']['text']
    precip_in_15 = response['forecast']['forecastday'][0]['hour'][15]['precip_in']
    humidity_15 = response['forecast']['forecastday'][0]['hour'][15]['humidity']
    temp_f_16 = response['forecast']['forecastday'][0]['hour'][16]['temp_f']
    condition_16 = response['forecast']['forecastday'][0]['hour'][16]['condition']['text']
    precip_in_16 = response['forecast']['forecastday'][0]['hour'][16]['precip_in']
    humidity_16 = response['forecast']['forecastday'][0]['hour'][16]['humidity']
    temp_f_17 = response['forecast']['forecastday'][0]['hour'][17]['temp_f']
    condition_17 = response['forecast']['forecastday'][0]['hour'][17]['condition']['text']
    precip_in_17 = response['forecast']['forecastday'][0]['hour'][17]['precip_in']
    humidity_17 = response['forecast']['forecastday'][0]['hour'][17]['humidity']
    temp_f_18 = response['forecast']['forecastday'][0]['hour'][18]['temp_f']
    condition_18 = response['forecast']['forecastday'][0]['hour'][18]['condition']['text']
    precip_in_18 = response['forecast']['forecastday'][0]['hour'][18]['precip_in']
    humidity_18 = response['forecast']['forecastday'][0]['hour'][18]['humidity']
    temp_f_19 = response['forecast']['forecastday'][0]['hour'][19]['temp_f']
    condition_19 = response['forecast']['forecastday'][0]['hour'][19]['condition']['text']
    precip_in_19 = response['forecast']['forecastday'][0]['hour'][19]['precip_in']
    humidity_19 = response['forecast']['forecastday'][0]['hour'][19]['humidity']
    temp_f_20 = response['forecast']['forecastday'][0]['hour'][20]['temp_f']
    condition_20 = response['forecast']['forecastday'][0]['hour'][20]['condition']['text']
    precip_in_20 = response['forecast']['forecastday'][0]['hour'][20]['precip_in']
    humidity_20 = response['forecast']['forecastday'][0]['hour'][20]['humidity']
    temp_f_21 = response['forecast']['forecastday'][0]['hour'][21]['temp_f']
    condition_21 = response['forecast']['forecastday'][0]['hour'][21]['condition']['text']
    precip_in_21 = response['forecast']['forecastday'][0]['hour'][21]['precip_in']
    humidity_21 = response['forecast']['forecastday'][0]['hour'][21]['humidity']
    temp_f_22 = response['forecast']['forecastday'][0]['hour'][22]['temp_f']
    condition_22 = response['forecast']['forecastday'][0]['hour'][22]['condition']['text']
    precip_in_22 = response['forecast']['forecastday'][0]['hour'][22]['precip_in']
    humidity_22 = response['forecast']['forecastday'][0]['hour'][22]['humidity']
    temp_f_23 = response['forecast']['forecastday'][0]['hour'][23]['temp_f']
    condition_23 = response['forecast']['forecastday'][0]['hour'][23]['condition']['text']
    precip_in_23 = response['forecast']['forecastday'][0]['hour'][23]['precip_in']
    humidity_23 = response['forecast']['forecastday'][0]['hour'][23]['humidity']

    dc_weather.append({'date': date, 'maxtemp_f': maxtemp_f, 'mintemp_f': mintemp_f, 'avgtemp_f': avgtemp_f,
                        'totalprecip_in': totalprecip_in, 'avghumidity': avghumidity, 'day_condition': day_condition,
                        '0_temp_f': temp_f_0, '0_condition': condition_0, '0_precip_in': precip_in_0, '0_humidity': humidity_0,
                        '1_temp_f': temp_f_1, '1_condition': condition_1, '1_precip_in': precip_in_1, '1_humidity': humidity_1,
                        '2_temp_f': temp_f_2, '2_condition': condition_2, '2_precip_in': precip_in_2, '2_humidity': humidity_2,
                        '3_temp_f': temp_f_3, '3_condition': condition_3, '3_precip_in': precip_in_3, '3_humidity': humidity_3,
                        '4_temp_f': temp_f_4, '4_condition': condition_4, '4_precip_in': precip_in_4, '4_humidity': humidity_4,
                        '5_temp_f': temp_f_5, '5_condition': condition_5, '5_precip_in': precip_in_5, '5_humidity': humidity_5,
                        '6_temp_f': temp_f_6, '6_condition': condition_6, '6_precip_in': precip_in_6, '6_humidity': humidity_6,
                        '7_temp_f': temp_f_7, '7_condition': condition_7, '7_precip_in': precip_in_7, '7_humidity': humidity_7,
                        '8_temp_f': temp_f_8, '8_condition': condition_8, '8_precip_in': precip_in_8, '8_humidity': humidity_8,
                        '9_temp_f': temp_f_9, '9_condition': condition_9, '9_precip_in': precip_in_9, '9_humidity': humidity_9,
                        '10_temp_f': temp_f_10, '10_condition': condition_10, '10_precip_in': precip_in_10, '10_humidity': humidity_10,
                        '11_temp_f': temp_f_11, '11_condition': condition_11, '11_precip_in': precip_in_11, '11_humidity': humidity_11,
                        '12_temp_f': temp_f_12, '12_condition': condition_12, '12_precip_in': precip_in_12, '12_humidity': humidity_12,
                        '13_temp_f': temp_f_13, '13_condition': condition_13, '13_precip_in': precip_in_13, '13_humidity': humidity_13,
                        '14_temp_f': temp_f_14, '14_condition': condition_14, '14_precip_in': precip_in_14, '14_humidity': humidity_14,
                        '15_temp_f': temp_f_15, '15_condition': condition_15, '15_precip_in': precip_in_15, '15_humidity': humidity_15,
                        '16_temp_f': temp_f_16, '16_condition': condition_16, '16_precip_in': precip_in_16, '16_humidity': humidity_16,
                        '17_temp_f': temp_f_17, '17_condition': condition_17, '17_precip_in': precip_in_17, '17_humidity': humidity_17,
                        '18_temp_f': temp_f_18, '18_condition': condition_18, '18_precip_in': precip_in_18, '18_humidity': humidity_18,
                        '19_temp_f': temp_f_19, '19_condition': condition_19, '19_precip_in': precip_in_19, '19_humidity': humidity_19,
                        '20_temp_f': temp_f_20, '20_condition': condition_20, '20_precip_in': precip_in_20, '20_humidity': humidity_20,
                        '21_temp_f': temp_f_21, '21_condition': condition_21, '21_precip_in': precip_in_21, '21_humidity': humidity_21,
                        '22_temp_f': temp_f_22, '22_condition': condition_22, '22_precip_in': precip_in_22, '22_humidity': humidity_22,
                        '23_temp_f': temp_f_23, '23_condition': condition_23, '23_precip_in': precip_in_23, '23_humidity': humidity_23})

dc_weather_df = pd.DataFrame(dc_weather)
dc_weather_df.head()
# Out:
#          date  maxtemp_f  mintemp_f  avgtemp_f  totalprecip_in  avghumidity  \
# 0  2022-02-06       40.5       24.1       32.8             0.0         52.0
# 1  2022-02-07       46.9       27.7       38.0             0.0         61.0
# 2  2022-02-08       45.0       32.9       39.1             0.0         59.0
# 3  2022-02-09       54.1       30.6       43.2             0.0         63.0
# 4  2022-02-10       54.5       34.9       45.3             0.0         68.0
#
#    day_condition  0_temp_f    0_condition  0_precip_in  ...  21_precip_in  \
# 0          Sunny      26.4          Clear          0.0  ...           0.0
# 1         Cloudy      27.9          Clear          0.0  ...           0.0
# 2         Cloudy      36.1  Partly cloudy          0.0  ...           0.0
# 3       Overcast      33.4  Partly cloudy          0.0  ...           0.0
# 4  Partly cloudy      39.0          Clear          0.0  ...           0.0
#
# ...

# %%
# Export the weather data into a csv
dc_weather_df.to_csv("output_data/dc_weather.csv", index_label="Date_ID")

# %%
# Open dc_weather.csv file
file = "output_data/dc_weather.csv"
weather_df = pd.read_csv(file)
weather_df.head()
# Out:
#    Date_ID        date  maxtemp_f  mintemp_f  avgtemp_f  totalprecip_in  \
# 0        0  2022-02-06       40.5       24.1       32.8             0.0
# 1        1  2022-02-07       46.9       27.7       38.0             0.0
# 2        2  2022-02-08       45.0       32.9       39.1             0.0
# 3        3  2022-02-09       54.1       30.6       43.2             0.0
# 4        4  2022-02-10       54.5       34.9       45.3             0.0
#
#    avghumidity  day_condition  0_temp_f    0_condition  ...  21_precip_in  \
# 0         52.0          Sunny      26.4          Clear  ...           0.0
# 1         61.0         Cloudy      27.9          Clear  ...           0.0
# 2         59.0         Cloudy      36.1  Partly cloudy  ...           0.0
# 3         63.0       Overcast      33.4  Partly cloudy  ...           0.0
# 4         68.0  Partly cloudy      39.0          Clear  ...           0.0
#
#    21_humidity  22_temp_f   22_condition  22_precip_in  22_humidity  \
# ...

# %%
# Divide original DC weather data frame by date and hour.
weather_by_hour = []

for index, row in weather_df.iterrows():
    
    # 12:00AM
    weather_by_hour.append({"date": row['date'], "hour": "12:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['0_temp_f'],
                            "hour_condition": row['0_condition'], "hour_precip_in": row['0_precip_in'],
                            "hour_humidity": row['0_humidity']})
    
    # 1:00AM
    weather_by_hour.append({"date": row['date'], "hour": "1:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['1_temp_f'],
                            "hour_condition": row['1_condition'], "hour_precip_in": row['1_precip_in'],
                            "hour_humidity": row['1_humidity']})
    
    # 2:00AM
    weather_by_hour.append({"date": row['date'], "hour": "2:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['2_temp_f'],
                            "hour_condition": row['2_condition'], "hour_precip_in": row['2_precip_in'],
                            "hour_humidity": row['2_humidity']})
    
    # 3:00AM
    weather_by_hour.append({"date": row['date'], "hour": "3:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['3_temp_f'],
                            "hour_condition": row['3_condition'], "hour_precip_in": row['3_precip_in'],
                            "hour_humidity": row['3_humidity']})    
   
    # 4:00AM
    weather_by_hour.append({"date": row['date'], "hour": "4:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['4_temp_f'],
                            "hour_condition": row['4_condition'], "hour_precip_in": row['4_precip_in'],
                            "hour_humidity": row['4_humidity']})
    # 5:00AM
    weather_by_hour.append({"date": row['date'], "hour": "5:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['5_temp_f'],
                            "hour_condition": row['5_condition'], "hour_precip_in": row['5_precip_in'],
                            "hour_humidity": row['5_humidity']})
    # 6:00AM
    weather_by_hour.append({"date": row['date'], "hour": "6:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['6_temp_f'],
                            "hour_condition": row['6_condition'], "hour_precip_in": row['6_precip_in'],
                            "hour_humidity": row['6_humidity']})
    # 7:00AM
    weather_by_hour.append({"date": row['date'], "hour": "7:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['7_temp_f'],
                            "hour_condition": row['7_condition'], "hour_precip_in": row['7_precip_in'],
                            "hour_humidity": row['7_humidity']})
    # 8:00AM
    weather_by_hour.append({"date": row['date'], "hour": "8:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['8_temp_f'],
                            "hour_condition": row['8_condition'], "hour_precip_in": row['8_precip_in'],
                            "hour_humidity": row['8_humidity']})

    # 9:00AM
    weather_by_hour.append({"date": row['date'], "hour": "9:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['9_temp_f'],
                            "hour_condition": row['9_condition'], "hour_precip_in": row['9_precip_in'],
                            "hour_humidity": row['9_humidity']})
    # 10:00AM
    weather_by_hour.append({"date": row['date'], "hour": "10:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['10_temp_f'],
                            "hour_condition": row['10_condition'], "hour_precip_in": row['10_precip_in'],
                            "hour_humidity": row['10_humidity']})    
    # 11:00AM
    weather_by_hour.append({"date": row['date'], "hour": "11:00AM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['11_temp_f'],
                            "hour_condition": row['11_condition'], "hour_precip_in": row['11_precip_in'],
                            "hour_humidity": row['11_humidity']})

    # 12:00PM
    weather_by_hour.append({"date": row['date'], "hour": "12:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['12_temp_f'],
                            "hour_condition": row['12_condition'], "hour_precip_in": row['12_precip_in'],
                            "hour_humidity": row['12_humidity']})
    
    # 1:00PM
    weather_by_hour.append({"date": row['date'], "hour": "1:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['13_temp_f'],
                            "hour_condition": row['13_condition'], "hour_precip_in": row['13_precip_in'],
                            "hour_humidity": row['13_humidity']})   
    # 2:00PM
    weather_by_hour.append({"date": row['date'], "hour": "2:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['14_temp_f'],
                            "hour_condition": row['14_condition'], "hour_precip_in": row['14_precip_in'],
                            "hour_humidity": row['14_humidity']})   
    # 3:00PM
    weather_by_hour.append({"date": row['date'], "hour": "3:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['15_temp_f'],
                            "hour_condition": row['15_condition'], "hour_precip_in": row['15_precip_in'],
                            "hour_humidity": row['15_humidity']})  
    
    # 4:00PM
    weather_by_hour.append({"date": row['date'], "hour": "4:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['16_temp_f'],
                            "hour_condition": row['16_condition'], "hour_precip_in": row['16_precip_in'],
                            "hour_humidity": row['16_humidity']})
    # 5:00PM
    weather_by_hour.append({"date": row['date'], "hour": "5:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['17_temp_f'],
                            "hour_condition": row['17_condition'], "hour_precip_in": row['17_precip_in'],
                            "hour_humidity": row['17_humidity']})
    # 6:00PM
    weather_by_hour.append({"date": row['date'], "hour": "6:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['18_temp_f'],
                            "hour_condition": row['18_condition'], "hour_precip_in": row['18_precip_in'],
                            "hour_humidity": row['18_humidity']})
    # 7:00PM
    weather_by_hour.append({"date": row['date'], "hour": "7:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['19_temp_f'],
                            "hour_condition": row['19_condition'], "hour_precip_in": row['19_precip_in'],
                            "hour_humidity": row['19_humidity']})
    # 8:00PM
    weather_by_hour.append({"date": row['date'], "hour": "8:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['20_temp_f'],
                            "hour_condition": row['20_condition'], "hour_precip_in": row['20_precip_in'],
                            "hour_humidity": row['20_humidity']})
    # 9:00PM
    weather_by_hour.append({"date": row['date'], "hour": "9:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['21_temp_f'],
                            "hour_condition": row['21_condition'], "hour_precip_in": row['21_precip_in'],
                            "hour_humidity": row['21_humidity']})
    # 10:00PM
    weather_by_hour.append({"date": row['date'], "hour": "10:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['22_temp_f'],
                            "hour_condition": row['22_condition'], "hour_precip_in": row['22_precip_in'],
                            "hour_humidity": row['22_humidity']})
    # 11:00PM
    weather_by_hour.append({"date": row['date'], "hour": "11:00PM", "maxtemp_f": row['maxtemp_f'],
                            "mintemp_f": row['mintemp_f'],"avgtemp_f": row['avgtemp_f'],
                            "totalprecip_in": row['totalprecip_in'],"avghumidity": row['avghumidity'],
                            "day_condition": row['day_condition'], "hour_temp_f": row['23_temp_f'],
                            "hour_condition": row['23_condition'], "hour_precip_in": row['23_precip_in'],
                            "hour_humidity": row['23_humidity']})

weather_hour_df = pd.DataFrame(weather_by_hour)
weather_hour_df
# Out:
#             date     hour  maxtemp_f  mintemp_f  avgtemp_f  totalprecip_in  \
# 0     2022-02-06  12:00AM       40.5       24.1       32.8             0.0
# 1     2022-02-06   1:00AM       40.5       24.1       32.8             0.0
# 2     2022-02-06   2:00AM       40.5       24.1       32.8             0.0
# 3     2022-02-06   3:00AM       40.5       24.1       32.8             0.0
# 4     2022-02-06   4:00AM       40.5       24.1       32.8             0.0
# ...          ...      ...        ...        ...        ...             ...
# 8755  2023-02-05   7:00PM       50.9       30.0       41.1             0.0
# 8756  2023-02-05   8:00PM       50.9       30.0       41.1             0.0
# 8757  2023-02-05   9:00PM       50.9       30.0       41.1             0.0
# 8758  2023-02-05  10:00PM       50.9       30.0       41.1             0.0
# 8759  2023-02-05  11:00PM       50.9       30.0       41.1             0.0
#
# ...

# %%
# Export the weather data into a csv
weather_hour_df.to_csv("output_data/dc_weather_by_hour.csv", index_label="Date_ID")

# %% [markdown]
# ### Data Exploration and Cleanup - Merging Weather and Crime Data

# %%
# access crime data and weather data
weather_file_path = "output_data/dc_weather_by_hour.csv"
crime_file_path = "Resources/clean_crime_data.csv"

# create a Pandas DataFrame for each file
weather_df = pd.read_csv(weather_file_path)
crime_df = pd.read_csv(crime_file_path)

# %%
# Review sample of weather data
weather_df.head()
# Out:
#    Date_ID        date     hour  maxtemp_f  mintemp_f  avgtemp_f  \
# 0        0  2022-02-06  12:00AM       40.5       24.1       32.8
# 1        1  2022-02-06   1:00AM       40.5       24.1       32.8
# 2        2  2022-02-06   2:00AM       40.5       24.1       32.8
# 3        3  2022-02-06   3:00AM       40.5       24.1       32.8
# 4        4  2022-02-06   4:00AM       40.5       24.1       32.8
#
#    totalprecip_in  avghumidity day_condition  hour_temp_f hour_condition  \
# 0             0.0         52.0         Sunny         26.4          Clear
# 1             0.0         52.0         Sunny         26.1          Clear
# 2             0.0         52.0         Sunny         25.8          Clear
# 3             0.0         52.0         Sunny         25.5          Clear
# 4             0.0         52.0         Sunny         25.0          Clear
#
#    hour_precip_in  hour_humidity
# 0             0.0             52
# 1             0.0             52
# ...

# %%
# Review sample of crime data
crime_df.head()
# Out:
#    Unnamed: 0  YEAR  START_DATE offensegroup              OFFENSE  \
# 0        5017  2022  2022-04-12      violent              robbery
# 1        5034  2022  2022-03-16     property         theft f/auto
# 2        5035  2022  2022-03-01     property         theft f/auto
# 3        5036  2022  2022-03-17     property  motor vehicle theft
# 4        5037  2022  2022-03-17     property  motor vehicle theft
#
#           offense-text                    offensekey START_TIME
# 0              robbery               violent|robbery   20:00:00
# 1         theft f/auto         property|theft f/auto   17:00:00
# 2         theft f/auto         property|theft f/auto   16:00:00
# 3  motor vehicle theft  property|motor vehicle theft   10:45:00
# 4  motor vehicle theft  property|motor vehicle theft   16:45:00

# %%
# Convert crime date type to match weather date type
crime_df['START_DATE'] = pd.to_datetime(crime_df['START_DATE'], format='%Y/%m/%d').dt.strftime('%Y-%m-%d')
# Check sample to see results
crime_df.head()
# Out:
#    Unnamed: 0  YEAR  START_DATE offensegroup              OFFENSE  \
# 0        5017  2022  2022-04-12      violent              robbery
# 1        5034  2022  2022-03-16     property         theft f/auto
# 2        5035  2022  2022-03-01     property         theft f/auto
# 3        5036  2022  2022-03-17     property  motor vehicle theft
# 4        5037  2022  2022-03-17     property  motor vehicle theft
#
#           offense-text                    offensekey START_TIME
# 0              robbery               violent|robbery   20:00:00
# 1         theft f/auto         property|theft f/auto   17:00:00
# 2         theft f/auto         property|theft f/auto   16:00:00
# 3  motor vehicle theft  property|motor vehicle theft   10:45:00
# 4  motor vehicle theft  property|motor vehicle theft   16:45:00

# %%
# Parse out hour from START_TIME
crime_df[['START_HOUR','START_MIN_SEC']] = crime_df['START_TIME'].str.split(':',n=1,expand=True)
crime_df.head()
# Out:
#    Unnamed: 0  YEAR  START_DATE offensegroup              OFFENSE  \
# 0        5017  2022  2022-04-12      violent              robbery
# 1        5034  2022  2022-03-16     property         theft f/auto
# 2        5035  2022  2022-03-01     property         theft f/auto
# 3        5036  2022  2022-03-17     property  motor vehicle theft
# 4        5037  2022  2022-03-17     property  motor vehicle theft
#
#           offense-text                    offensekey START_TIME START_HOUR  \
# 0              robbery               violent|robbery   20:00:00         20
# 1         theft f/auto         property|theft f/auto   17:00:00         17
# 2         theft f/auto         property|theft f/auto   16:00:00         16
# 3  motor vehicle theft  property|motor vehicle theft   10:45:00         10
# 4  motor vehicle theft  property|motor vehicle theft   16:45:00         16
#
#   START_MIN_SEC
# 0         00:00
# 1         00:00
# 2         00:00
# 3         45:00
# 4         45:00

# %%
# Create an hour list based on 'START_HOUR' to match 00:00AM/PM weather hour format
# Make a list out of 'START_HOUR' column.
hour_num_list = crime_df["START_HOUR"].values.tolist()

# Create a new list for the hours
hour_list = []

# Iterate over the 'START_HOUR' column to create hour list.
for hour in hour_num_list:
    if hour == "00":
        hour_list.append("12:00AM")
    elif hour == "01":
        hour_list.append("1:00AM")
    elif hour == "02":
        hour_list.append("2:00AM")
    elif hour == "03":
        hour_list.append("3:00AM")
    elif hour == "04":
        hour_list.append("4:00AM")
    elif hour == "05":
        hour_list.append("5:00AM")
    elif hour == "06":
        hour_list.append("6:00AM")
    elif hour == "07":
        hour_list.append("7:00AM")
    elif hour == "08":
        hour_list.append("8:00AM")
    elif hour == "09":
        hour_list.append("9:00AM")
    elif hour == "10":
        hour_list.append("10:00AM")
    elif hour == "11":
        hour_list.append("11:00AM")
    elif hour == "12":
        hour_list.append("12:00PM")
    elif hour == "13":
        hour_list.append("1:00PM")
    elif hour == "14":
        hour_list.append("2:00PM")
    elif hour == "15":
        hour_list.append("3:00PM")
    elif hour == "16":
        hour_list.append("4:00PM")
    elif hour == "17":
        hour_list.append("5:00PM")
    elif hour == "18":
        hour_list.append("6:00PM")
    elif hour == "19":
        hour_list.append("7:00PM")
    elif hour == "20":
        hour_list.append("8:00PM")
    elif hour == "21":
        hour_list.append("9:00PM")
    elif hour == "22":
        hour_list.append("10:00PM")
    elif hour == "23":
        hour_list.append("11:00PM")

# Add new hour list to DataFrame
crime_df['Hour'] = hour_list
crime_df.head()
# Out:
#    Unnamed: 0  YEAR  START_DATE offensegroup              OFFENSE  \
# 0        5017  2022  2022-04-12      violent              robbery
# 1        5034  2022  2022-03-16     property         theft f/auto
# 2        5035  2022  2022-03-01     property         theft f/auto
# 3        5036  2022  2022-03-17     property  motor vehicle theft
# 4        5037  2022  2022-03-17     property  motor vehicle theft
#
#           offense-text                    offensekey START_TIME START_HOUR  \
# 0              robbery               violent|robbery   20:00:00         20
# 1         theft f/auto         property|theft f/auto   17:00:00         17
# 2         theft f/auto         property|theft f/auto   16:00:00         16
# 3  motor vehicle theft  property|motor vehicle theft   10:45:00         10
# 4  motor vehicle theft  property|motor vehicle theft   16:45:00         16
#
#   START_MIN_SEC     Hour
# 0         00:00   8:00PM
# 1         00:00   5:00PM
# 2         00:00   4:00PM
# ...

# %%
crime_df = crime_df[['YEAR','START_DATE','START_TIME','Hour','offensegroup','OFFENSE','offense-text']]
crime_df.head()
# Out:
#    YEAR  START_DATE START_TIME     Hour offensegroup              OFFENSE  \
# 0  2022  2022-04-12   20:00:00   8:00PM      violent              robbery
# 1  2022  2022-03-16   17:00:00   5:00PM     property         theft f/auto
# 2  2022  2022-03-01   16:00:00   4:00PM     property         theft f/auto
# 3  2022  2022-03-17   10:45:00  10:00AM     property  motor vehicle theft
# 4  2022  2022-03-17   16:45:00   4:00PM     property  motor vehicle theft
#
#           offense-text
# 0              robbery
# 1         theft f/auto
# 2         theft f/auto
# 3  motor vehicle theft
# 4  motor vehicle theft

# %%
# Merge crime dataframe with weather dataframe
crime_weather = pd.merge(crime_df, weather_df, how='left', left_on=['START_DATE','Hour'], right_on=['date','hour'])
# Remove all rows outside of date range
crime_weather.dropna(how='any', inplace=True)
# Sort by start date and time
crime_weather.sort_values(["date", "START_TIME"], ascending=True, inplace=True)
# Reset Index
crime_weather.reset_index(drop=True, inplace=True)
# Remove redundant and unnecessary columns
crime_weather = crime_weather[['YEAR', 'START_DATE', 'START_TIME', 'Hour', 'offensegroup', 'OFFENSE',
       'offense-text','maxtemp_f', 'mintemp_f','avgtemp_f', 'totalprecip_in', 'avghumidity', 'day_condition',
       'hour_temp_f', 'hour_condition', 'hour_precip_in', 'hour_humidity']]
# Rename columns for cleaner presentation
crime_weather.rename(columns={"YEAR": "Year", "START_DATE": "Start Date", "START_TIME": "Start Time",
                    "offensegroup": "Offense Group", 'OFFENSE': 'Offense', 'offense-text': 'Offense Text',
                    'maxtemp_f': 'Max Temp (f)', 'mintemp_f': 'Min Temp (f)', 'avgtemp_f': 'Avg Temp (f)',
                    'totalprecip_in': 'Total Precipitation (in)', 'avghumidity': 'Avg Humidity (%)',
                    'day_condition': 'Day Condition', 'hour_temp_f': 'Hour Temp (f)', 'hour_condition': 'Hour Condition',
                    'hour_precip_in': 'Hour Precipitation (in)','hour_humidity': 'Hour Humidity (%)'}, inplace=True)
# View results
crime_weather
# Out:
#        Year  Start Date Start Time     Hour Offense Group  \
# 0      2022  2022-02-06   00:12:00  12:00AM       violent
# 1      2022  2022-02-06   00:19:00  12:00AM      property
# 2      2022  2022-02-06   01:00:00   1:00AM      property
# 3      2022  2022-02-06   01:30:00   1:00AM      property
# 4      2022  2022-02-06   02:45:00   2:00AM       violent
# ...     ...         ...        ...      ...           ...
# 27556  2023  2023-02-05   23:00:00  11:00PM       violent
# 27557  2023  2023-02-05   23:00:00  11:00PM      property
# 27558  2023  2023-02-05   23:21:00  11:00PM      property
# 27559  2023  2023-02-05   23:40:00  11:00PM      property
# 27560  2023  2023-02-05   23:55:00  11:00PM      property
#
#                           Offense                Offense Text  Max Temp (f)  \
# 0                         robbery                     robbery          40.5
# 1                     theft/other                 theft/other          40.5
# ...

# %%
# Export the merged dataframe
crime_weather.to_csv("output_data/crime_weather_merged.csv", index_label="ID")
